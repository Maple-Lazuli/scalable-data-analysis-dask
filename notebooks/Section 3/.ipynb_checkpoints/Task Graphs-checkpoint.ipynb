# %%
from dask import delayed, compute

@delayed
def do_something_1(x, y):
    return x + y + 2*x*y

@delayed
def do_something_2(a, b):
    return a**3 - b**3

@delayed
def do_something_3(p, q):
    return p*p + q*q

len_arr = 3
x = [i*2 for i in range(1, len_arr+1)]
y = [i*3 for i in range(1, len_arr+1)]
z = [i*10 for i in range(1, len_arr+1)]

final_result = []

final_result = []
for i in range(0, len(x)):
    res_1 = do_something_1(x[i], y[i])
    res_2 = do_something_2(y[i], z[i])
    res_3 = do_something_3(res_1, res_2)
    final_result.append(res_3)

final_sum = delayed(sum)(final_result)

# %%
final_sum.visualize()

# %%
import dask.array as da

arr1 = da.ones(15, chunks=3)
arr2 = da.ones(15, chunks=3)

print("Chunks are {}".format(arr1.chunks))
sum_arr = da.add(arr1, arr2)
mean_arr = da.mean(sum_arr)

mean_arr.visualize(rankdir="LR")
# Out:
# Chunks are ((3, 3, 3, 3, 3),)

# %%
arr1.chunks
# Out:
# ((3, 3, 3, 3, 3),)

# %%
da.dot(arr1.T, arr2).visualize(rankdir="LR")

# %% [markdown]
# ## Creating your own task graphs

# %%
def do_something_1(x, y):
    return x + y + 2*x*y

def do_something_2(a, b):
    return a**3 - b**2

def do_something_3(p, q):
    return p*p + q*q

def do_something_4(x):
    return x * 3

# %%
dsk = {
        'thrice_1': (do_something_4, 10),
        'thrice_2': (do_something_4, 20),
        'thrice_3': (do_something_4, 30),
        'thrice_4': (do_something_4, 40),
        'square_sum': (do_something_3,
                       'thrice_1', 'thrice_2'),
        'a_plus_b_wholeSquare': (do_something_1,
                                 'square_sum', 'thrice_3'),
        'some_complex_stuff': (do_something_2,
                               'thrice_4', 'a_plus_b_wholeSquare')}

# %%
from dask.multiprocessing import get
my_task = get(dsk, 'some_complex_stuff')

# %%
import dask
dask.visualize(dsk, rankdir="LR")

# %%
dask.visualize(dsk, filename='/home/kashif/Pictures/task_graph.jpeg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 dask.visualize(dsk, filename='/home/kashif/Pictures/task_graph.jpeg')
#
# File ~/CodeProjects/scalable-dask/venv/lib/python3.10/site-packages/dask/base.py:797, in visualize(filename, traverse, optimize_graph, maxval, engine, *args, **kwargs)
#     794 if engine == "graphviz":
#     795     from dask.dot import dot_graph
# --> 797     return dot_graph(dsk, filename=filename, **kwargs)
#     798 elif engine in ("cytoscape", "ipycytoscape"):
#     799     from dask.dot import cytoscape_graph
#
# File ~/CodeProjects/scalable-dask/venv/lib/python3.10/site-packages/dask/dot.py:274, in dot_graph(dsk, filename, format, **kwargs)
#     236 """
#     237 Render a task graph using dot.
#     238
#    (...)
#     271 dask.dot.to_graphviz
#     272 """
#     273 g = to_graphviz(dsk, **kwargs)
# --> 274 return graphviz_to_file(g, filename, format)
#
# File ~/CodeProjects/scalable-dask/venv/lib/python3.10/site-packages/dask/dot.py:307, in graphviz_to_file(g, filename, format)
#     304     return display_cls(data=data)
#     306 full_filename = ".".join([filename, format])
# --> 307 with open(full_filename, "wb") as f:
#     308     f.write(data)
#     310 return display_cls(filename=full_filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/kashif/Pictures/task_graph.jpeg'
